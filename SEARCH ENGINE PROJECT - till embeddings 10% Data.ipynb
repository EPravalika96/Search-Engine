# %%
import zipfile
import io

import sqlite3

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sentence_transformers import SentenceTransformer

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


import numpy as np
import pandas as pd

# %% [markdown]
# ## **Step 1 - Reading the Tables from Database file**

# %%
# Read the code below and write your observation in the next cell

conn = sqlite3.connect('eng_subtitles_database.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
# Out:
# [('zipfiles',)]

# %% [markdown]
# **In the above cell, I am able to read the table inside the database. As mentioned earlier, table name is `zipfiles`. We also know from README.txt that this table contains three columns: 'num', 'name' and 'content'.**

# %% [markdown]
# ## **Step 2 - Reading the columns of Table**

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# num
# name
# content

# %% [markdown]
# **The above code helps in checking the column names in the database table.**
#
# **Let's now use `SELECT * FROM zipfiles` to read all the data into a `df` variable.**

# %% [markdown]
# ## **Step 3 - Loading the Database Table inside a Pandas DataFrame**

# %%
df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df = df.sample(frac=0.1)
df.head()
# Out:
#            num                                               name  \
# 18230  9254799  charmed.s05.e19.nymphs.just.wanna.have.fun.(20...
# 5064   9203148  american.gothic.s01.e05.the.artist.in.his.muse...
# 51601  9397935  call.the.midwife.christmas.special.2022.(2022)...
# 11270  9228156  dynasty.s05.e20.first.kidnapping.and.now.theft...
# 34937  9321247  harry.wild.s01.e04.an.unhappy.happy.is.a.dange...
#
#                                                  content
# 18230  b'PK\x03\x04\x14\x00\x00\x00\x08\x004\xab\x99V...
# 5064   b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\x8d\x99V...
# 51601  b'PK\x03\x04\x14\x00\x00\x00\x08\x00%%\x9aVx\x...
# 11270  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xc8\x94\x...
# 34937  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x81\xb2\x...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8250 entries, 18230 to 68553
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   num      8250 non-null   int64
#  1   name     8250 non-null   object
#  2   content  8250 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 257.8+ KB

# %% [markdown]
# **Looks like the `content` column donot contain the subtitles text. Instead as mentioned in README.txt, it might be latin-1 encoded.**

# %% [markdown]
# ## **Step 4 - Printing `content` of 0th Row**

# %%
b_data = df.iloc[0, 2]

# here 2 represent the index of content column
# 0 represents the row number

# %%
print(b_data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x004\xab\x99V\xae\x9a\x1a+]V\x00\x00\x1f\xdf\x00\x00A\x00\x00\x00Charmed S05E19 Nymphs Just Wanna Have Fun.DVDRip.HI.cc.en.CBS.srt}\xbd\xcd\x92\xdc\xd6\x92?\xb6g\x04\xdf\x01W\x0bkSl\x038\xf8TL\\\x06%Qd\x8f)\x92AR\x97C+f\x81\xaeBw\xe1\xb2\xaaPS\xa8b\xab\xe7M\xbc\xf3\xd6~\x05/\xbc\xf8\xbf\x89_\xc0\xaf\xe0\xfce\xe6I$ZW\x8e\xb83!\xa2\xeb\xe4\x01\xce\xc9\xef\xcf\xff\xf7\xff\xfa\xbf\xb3\xa7O\xd2\xf4\x07\xfc/[5\xa1L\x9e=\xfb{\xa2\x0f\x8aU^\xb5O\x9f\xfc\xfe\xfe\xc5\xdb\xf7\xd7\xef_&\xef\xdf\xbc\xf8r\xfd\xf6\xd5\x7f>}\xf2\xf4I\x1e\x97\xe5\xe5*\xcf\xfd\xb2\xbcYUm\xf1\xf4\xc9\x7f\xbc\xf8\xc7\xf5\xcb\x0f?$\xd7\xc9\xdd\xa5\x9f\xa6d\xff\x90\x0c\x87o\xc3\xb9;\x0f\xe3\xe1\xe9\x93\xfde:\x7f\xff\xadO\xee\xc6\xf3\xb9?$\xbbq:\xd3\xdf\x93\xf3\xb6O\xf6\xdd\xb0\xbb\xc2&\xc16iVu[\xb9MB\xbe\xaaB\xfa\xf4\xc93\x02\x7f\x1ew\x9b\xe4a\xbc$\xd7\xdfo\x92\xdb\xe1 \xff\xe8\xee\xba\xe1\xb0z\xfad\xea\xce\x0f\xa7+\xfc\xf2\xd3\xb6?\xf5\xdfO\xc9a<o\x87\xc3]r;\x9e\xf8\x97x\xcc\xdb\x15q;\x82^\x87\xe0\xb7+VM]\x03\xc8\x9b\xbe\xa3\x97&\x00Sr\xdcu\xeb>! \xd7\xdf\xefvWW\xbcG\xfc\xe8w\x0c\x9a\x9e\'\xf7\xdb\xee\xfc\x1c\xd0K\x83^\xac\xda4\xf3\xd0\xebU\x96\xd2\x81~\xa1\x97\xb9\x1b\x0f\x87\x0e\xa0\x1f\x00\xe0\x94\xdc\xee.\xe7\x9e\xd7W\xb6\xbe^\xe5i\xe1\xd7\xb7\xabP\xd3=\xfe\xfe\xf1\xa7\x0f/_\xfc\x1a\xaf\xa8\x8e\x0b\x8avUe\xfe\xf4\xcal\xd5f\xf4\xe7\xcf\xdb1\xe9N=vz\x9e|\xa6\x17M6#\x1f\xc9}w\x90\x97n"\x8c2_\xa5Y\xeba\x14\xab\xb2\xa1w\xba\xe6\x1f\xf3\xaa\xf3\x98L\xdb\xf1>\xd9\xf7O\x9f\xe0\x1e_\x9e\xfb\xd3\xa1\xdb%\x1f\x8f\':\xef\x15\x9dZw\xa6\xf3\xc7\x89\xf0y\xb7\x06\xbcXUM\xe3\x81\xb7\xab\xbc\xa5/\xfa\xed\xb0#\xd4Y%\xe3m\xb2\xa6\xd3\x98z\xba\xd0\xf8~\xd8\xae\xa7\xcb\xbe\x1c\x9f>\xd9\r_{9\xaf\xe3H\x17\xc2w>\xdfk\x96\xdaFtR\xed|\xb1\xd9\x0fi\xbe\xca*\xfa\xf3\xbb\xc3\xee\x81\x16$\xeb\x8eP\xb0\xa7k\xbbLO\x9f\xdco\t1i\x97S\xff\xad\xa7\xcf\xc0\'M\xfc)\x02U)\'\x03\xa1\x14m\xe3\xa1\x96\xab\x16\xd8\xa9\xd8\xf0\xf4\xc9[:\x95\xeb\xef\xf7\x0c\x1a\xa8G\xaf*0r\x83Q\xad\xd2\x90{\x18\xf5\xaa\xa9*\xdc\x11}FB\xe86\xc8\x8dd!.\xc9\xc3*\x94\xa9[B\xa4X\xe2Z\xe9J\x06\xfa\x84H\n\x7f\xe3e\x85-kVY\xe3\xdf6o\xe9&i\xd9O\xe3\xe1\xee\xd4\x9d/;\xa6\xd0I)(y\xbf\x1d\xfb\x1b=\xc8\xd2\x80\x10J5\xad\x03B$\x93\xe7\x85\x90Yw\xf8Jw6\xdd\xf7\xfdy\xe8\xaf\x92W\xe3\xb8I\x0e\xc3\xdd\xf6\xcc$\xf2\xf9\xdd\xaf/\xde\xfe\x90|\xec\xfb\xf9\x18\xaa\x08\x97\xc0\x84\xbc\xf2p\xabU\tn"\xc7\x10\x91\xf5\xd1\xbfW\x84S\xcb?\x13\xcc:\xc2,\xd2U\x93\xfas*\xcaU\x9d\xf2\xbb\xfe\xfb\x8b\x8f\xef\xe8]~\x1e\x84g\x10\x13\xa2+\x1e\xf7=3\x88\xe7\xfc\x0bbS`]7\':\x8c\xa4\xa3\x13\xa5\x7f|\xed\x1f&y\xf1\xc66)i\x13\xff\xe2E\xb3*j\xba\xab\xcft\xe5+0\xc1\xf1\xcc\xa0\t\xc5n\x88\x06\xba\xe1L[\x10\x9d\x8c\xc9\xb9#\xe4\xbdL\xc9\x16\x7f\xdd\x8c\xf7\x87\xe9\xdc\r\'\xdd\xa0\xb5\r\x9aUY\x97n\x03"\xe2\xbaf\x02<\xf4\xfd\x06x\xca\x17\xae\xafG{\x11\xa3\xbb\x197\x0fO\x9fl\xbb\t\x7f\xbe\xe7}\x8e\xf8\xcf]O\x1fEXu\xe0M\xf24nB0\x9b\xda\xe3\x06Qf(h\x93\xf7\xc3\xb1?\tZ}\xc5\xff\x03\x89\x0f\xb7\xc9\xf5\x0c\x94\x88\xe3\xa6\xbby\x10\x80F\x1a\xb4\xbe(\x16\x00\xabU\xd1d\xf1X\xee\xb7\x0f\xf4\xc5\x87\xef\x85\x7f\xd0w?0\xd5\xf2\x05\xe6F\x1b\xb4\xa6l<\xd5\x12\x197U\xc0\xa7\xef{"\xd8\xe1|\xa5\x07\x8c\xb7`\xb6\xfc\xf4\t\xb8;\xfey\xbf\x1dw\xbd\xa0\x1f\xa4\x01\x9d1\x0e%\x19/\xf4\x00Gq\xa1+\x1f\x84\x1f\xe5FZ\xd8\xa0\xa9m\xc7\x9c\x85#\x8e\xe9\xdd\xd6\xd8\x18\xe3\xb7\xacS\xda\xe2\x9f\xb5y\xee\xd7\xd1\xf95\xad\'\x8b\x9b\xcb\x99^\x96\xf8\xcc\xf7B\x0e\x1f/\x82\xb4x$\xd0J\x83\x06\xbe\x92yh\x84d9\x7f\xf7p\x98\x86Iw\xaf\xec\xf7\xc4v\x9c(\xa6\x07\xc4Fs\xa6\xec\xdde\x7f\xa0\x05`\xa48\x94\x87\xbe;=\xc7sB\x82\x91h\x1c\xfbo\xfa\xa9?}\x9b\x0f\xa36\xb0\xc44\xf3\xd6\x81\xcd\xe8+q\xfc\x1fw}\x7fL\xc0#\xb6\x10\x8a7\xa7\xbe\xfbz\xdbM8gZ\xdf\xc4\xf5\x19\x89\x8e\xca\xbfVV\xae\x8a@gvGX\xd8\x91\xb4\x9f\xa6\xee\x8e\xf8\xc45Nu<\xd0\x9d\xca\x0b\xb4\x06\x80\x04^\xf0\xb7\x91\xb5\xab4e\xa6\xa0\xb25\xa4\xf6\xdb\x96di\xe5~\x9bg\xab\ntH\xc2\xf5{:\xe9\x7f\x82\x9e;b\xe9\xdd\x8e8\xfea \t~wyP\xb1\xf2\xf5@|\xfal@\xb3\x084\x07\xa9\xf9/ N[\x15\x91\xdb\xe1\xb5\x19,Nv\xbd\xed\xf6\xc7\xee\xee\x00\ ...

# %% [markdown]
# **From the content, it appears to start with the bytes "PK\x03\......", which suggests that it might be a ZIP archive file. How do I know it? Experience! I have worked with something similar earlier.**

# %% [markdown]
# ## **Step 5 - Unzipping the content of 380th row and decoding using `latin-1`**

# %%
import zipfile
import io

# Assuming 'content' is the binary data from your database
binary_data = df.iloc[380, 2]

# Decompress the binary data using the zipfile module
with io.BytesIO(binary_data) as f:
    with zipfile.ZipFile(f, 'r') as zip_file:
        # Reading only one file in the ZIP archive
        subtitle_content = zip_file.read(zip_file.namelist()[0])

# Now 'subtitle_content' should contain the extracted subtitle content
print(subtitle_content.decode('latin-1'))  # Assuming the content is latin-1 encoded text
# Out:
# ï»¿[Script Info]
# Title: Default file
# ScriptType: v4.00+
# WrapStyle: 0
# PlayResX: 720
# PlayResY: 480
# ScaledBorderAndShadow: yes
# Audio File:
# Video File:
# Video Aspect Ratio: 0
# Video Zoom: 6
# Video Position: 0
#
# [V4+ Styles]
# Format: Name, Fontname, Fontsize, PrimaryColour, SecondaryColour, OutlineColour, BackColour, Bold, Italic, Underline, StrikeOut, ScaleX, ScaleY, Spacing, Angle, BorderStyle, Outline, Shadow, Alignment, MarginL, MarginR, MarginV, Encoding
# Style: Dialogue1,Tahoma,32,&H00BABABA,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
# Style: Dialogue2,Tahoma,29,&H00BABABA,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
# Style: Dialogue3,Tahoma,25,&H00BABABA,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
#
# [Events]
# Format: Layer, Start, End, Style, Name, MarginL, MarginR, MarginV, Effect, Text
# Dialogue: 0,0:00:05.23,0:00:06.67,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(254,368)}Mom, you're going
# Dialogue: 0,0:00:05.23,0:00:06.67,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(234,400)}to college now, right?
# Dialogue: 0,0:00:06.87,0:00:08.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,399)}Yes, I am, sweetie.
# Dialogue: 0,0:00:08.54,0:00:10.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(286,368)}Can you take
# Dialogue: 0,0:00:08.54,0:00:10.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(228,400)}cooking classes there?
# Dialogue: 0,0:00:13.18,0:00:15.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,368)}I thought you liked
# Dialogue: 0,0:00:13.18,0:00:15.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(254,400)}my tuna casserole.
# Dialogue: 0,0:00:15.48,0:00:17.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(292,365)}It was better
# Dialogue: 0,0:00:15.48,0:00:17.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,400)}when you made it drunk.
# Dialogue: 0,0:00:20.02,0:00:22.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,367)}Roscoe, I made it
# Dialogue: 0,0:00:20.02,0:00:22.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(238,397)}when she was drunk.
# Dialogue: 0,0:00:25.02,0:00:26.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(272,400)}Mystery solved.
# Dialogue: 0,0:00:28.46,0:00:29.86,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,86)}Sorry.
# Dialogue: 0,0:00:30.03,0:00:31.02,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}(GRUNTS)
# Dialogue: 0,0:00:31.16,0:00:32.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,365)}You would not believe
# Dialogue: 0,0:00:31.16,0:00:32.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(258,397)}what I snaked out
# Dialogue: 0,0:00:32.96,0:00:34.52,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,368)}of old Lady Gorman's
# Dialogue: 0,0:00:32.96,0:00:34.52,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(282,397)}shower drain.
# Dialogue: 0,0:00:34.76,0:00:36.06,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(286,368)}Mom, please.
# Dialogue: 0,0:00:34.76,0:00:36.06,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,400)}We're eating dinner.
# Dialogue: 0,0:00:36.27,0:00:37.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(235,400)}And it's hard enough.
# Dialogue: 0,0:00:39.10,0:00:40.13,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,83)}Fine.
# Dialogue: 0,0:00:42.04,0:00:43.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(305,365)}A hairball
# Dialogue: 0,0:00:42.04,0:00:43.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,397)}with a human tooth in it.
# Dialogue: 0,0:00:46.64,0:00:47.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(180,400)}I'm gonna go do my homework.
# Dialogue: 0,0:00:49.04,0:00:50.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(265,400)}Congratulations.
# Dialogue: 0,0:00:50.21,0:00:52.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,368)}You managed to gross out a boy
# Dialogue: 0,0:00:50.21,0:00:52.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(181,400)}who keeps his boogers in a jar.
# Dialogue: 0,0:00:54.55,0:00:55.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,400)}I need to get going, too.
# Dialogue: 0,0:00:56.69,0:00:57.74,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}Where you headed?
# Dialogue: 0,0:00:58.12,0:01:00.21,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,86)}I'm going to a birthday party
# Dialogue: 0,0:00:58.12,0:01:00.21,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}with Gregory.
# Dialogue: 0,0:01:00.76,0:01:03.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,400)}Oh, Gregory again.
# Dialogue: 0,0:01:03.23,0:01:05.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,368)}Wow, that's been going on
# Dialogue: 0,0:01:03.23,0:01:05.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,399)}a little while now, huh?
# Dialogue: 0,0:01:05.23,0:01:06.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(317,400)}I guess.
# Dialogue: 0,0:01:06.43,0:01:07.45,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}When do we get to meet him?
# Dialogue: 0,0:01:07.66,0:01:09.83,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,85)}Yeah, I'd like to meet
# Dialogue: 0,0:01:07.66,0:01:09.83,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}young Gregory.
# Dialogue: 0,0:01:10.03,0:01:12.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(241,368)}Yeah, I just don't see
# Dialogue: 0,0:01:10.03,0:01:12.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,400)}any reason for that.
# Dialogue: 0,0:01:14.04,0:01:16.90,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,85)}Oh, come on.
# Dialogue: 0,0:01:14.04,0:01:16.90,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}There's nothing to hide.
# Dialogue: 0,0:01:17.11,0:01:19.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(251,368)}Your last boyfriend
# Dialogue: 0,0:01:17.11,0:01:19.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,400)}was a burger-flipping stoner
# Dialogue: 0,0:01:19.54,0:01:21.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(229,368)}who got you pregnant.
# Dialogue: 0,0:01:19.54,0:01:21.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,400)}The bar is very low.
# Dialogue: 0,0:01:23.11,0:01:24.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(210,368)}Why are you so interested
# Dialogue: 0,0:01:23.11,0:01:24.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(302,400)}in my life?
# Dialogue: 0,0:01:25.01,0:01:26.88,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}- Are your own lives that boring?
# Dialogue: 0,0:01:25.01,0:01:26.88,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,115)}- Yes.
# Dialogue: 0,0:01:27.08,0:01:28.38,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}The most exciting thing
# Dialogue: 0,0:01:27.08,0:01:28.38,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,118)}that happened to me today
# Dialogue: 0,0:01:28.58,0:01:30.18,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,83)}was a hairball with an overbite.
# Dialogue: 0,0:01:31.92,0:01:34.08,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(306,365)}Come on.
# Dialogue: 0,0:01:31.92,0:01:34.08,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,397)}Tell me about him.
# Dialogue: 0,0:01:34.29,0:01:36.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(271,365)}I'm a cool mom.
# Dialogue: 0,0:01:34.29,0:01:36.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,400)}I'm hip, I'm happening.
# Dialogue: 0,0:01:37.93,0:01:39.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,400)}I got it going on.
# Dialogue: 0,0:01:40.26,0:01:42.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,400)}How were you ever a stripper?
# Dialogue: 0,0:01:45.53,0:01:47.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(146,400)}Some men enjoyed my awkwardness.
# Dialogue: 0,0:01:49.07,0:01:50.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(306,367)}Come on,
# Dialogue: 0,0:01:49.07,0:01:50.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,400)}what's the deal with this guy?
# Dialogue: 0,0:01:50.81,0:01:52.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(254,367)}Does he have, like,
# Dialogue: 0,0:01:50.81,0:01:52.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,400)}a misshapen head?
# Dialogue: 0,0:01:52.34,0:01:53.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,400)}Little tiny legs? Lazy eye?
# Dialogue: 0,0:01:54.04,0:01:55.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(299,397)}Canadian?
# Dialogue: 0,0:01:55.88,0:01:57.04,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(288,397)}"Canadian"?
# Dialogue: 0,0:01:57.25,0:01:58.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,365)}That's the border
# Dialogue: 0,0:01:57.25,0:01:58.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,400)}we should be watching.
# Dialogue: 0,0:02:01.32,0:02:03.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,368)}- He's just a guy.
# Dialogue: 0,0:02:01.32,0:02:03.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(221,400)}- Where'd you meet him?
# Dialogue: 0,0:02:03.52,0:02:05.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(298,365)}- At school.
# Dialogue: 0,0:02:03.52,0:02:05.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,399)}- So, he's a student.
# Dialogue: 0,0:02:05.35,0:02:08.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,368)}God. What is with you guys?
# Dialogue: 0,0:02:05.35,0:02:08.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,397)}Just leave it alone.
# Dialogue: 0,0:02:08.32,0:02:09.45,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(254,397)}He's not a student.
# Dialogue: 0,0:02:10.09,0:02:11.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(171,400)}Violet, you know the kind of men
# Dialogue: 0,0:02:11.76,0:02:12.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,368)}your grandmother and I
# Dialogue: 0,0:02:11.76,0:02:12.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,397)}have dated.
# Dialogue: 0,0:02:13.10,0:02:14.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,368)}We are the last people
# Dialogue: 0,0:02:13.10,0:02:14.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,400)}in the world to judge.
# Dialogue: 0,0:02:15.06,0:02:16.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,368)}- Am I right?
# Dialogue: 0,0:02:15.06,0:02:16.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(265,400)}- Mm. Absolutely.
# Dialogue: 0,0:02:16.47,0:02:17.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,397)}You cannot shock us.
# Dialogue: 0,0:02:18.53,0:02:19.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(310,400)}All right.
# Dialogue: 0,0:02:20.04,0:02:23.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,368)}He's a professor at my school.
# Dialogue: 0,0:02:20.04,0:02:23.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,400)}And he's 42 years old.
# Dialogue: 0,0:02:28.31,0:02:29.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,400)}I'm calling the police.
# Dialogue: 0,0:02:32.08,0:02:33.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,400)}âª (THEME MUSIC) âª
# Dialogue: 0,0:02:49.40,0:02:50.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(289,399)}Mom, I'm 19.
# Dialogue: 0,0:02:51.00,0:02:53.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,368)}No one's doing anything wrong.
# Dialogue: 0,0:02:51.00,0:02:53.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,400)}Hang up the phone.
# Dialogue: 0,0:02:54.64,0:02:56.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,368)}Then why were you hiding this
# Dialogue: 0,0:02:54.64,0:02:56.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(308,397)}from us?
# Dialogue: 0,0:02:56.81,0:02:58.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,365)}Because I was afraid
# Dialogue: 0,0:02:56.81,0:02:58.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,400)}you might not handle it well.
# Dialogue: 0,0:02:59.14,0:03:00.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,400)}Why would you think that?
# Dialogue: 0,0:03:00.68,0:03:01.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,400)}My little girl is dating a man
# Dialogue: 0,0:03:02.08,0:03:03.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(256,368)}who's old enough
# Dialogue: 0,0:03:02.08,0:03:03.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,397)}to be her father.
# Dialogue: 0,0:03:03.28,0:03:05.54,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,368)}Why would that upset me?
# Dialogue: 0,0:03:03.28,0:03:05.54,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(204,400)}It's just Jim frigging Dandy.
# Dialogue: 0,0:03:08.05,0:03:09.52,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,400)}You're not handling it well.
# Dialogue: 0,0:03:11.75,0:03:12.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(280,397)}I'm outta here.
# Dialogue: 0,0:03:13.56,0:03:14.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(267,397)}I don't believe it.
# Dialogue: 0,0:03:15.32,0:03:16.72,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}42 years old?
# Dialogue: 0,0:03:17.33,0:03:18.88,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,83)}It'd be less weird
# Dialogue: 0,0:03:17.33,0:03:18.88,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,118)}if you were dating him.
# Dialogue: 0,0:03:20.16,0:03:21.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,399)}Look, I haven't seen him,
# Dialogue: 0,0:03:21.40,0:03:23.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,368)}but if you want me
# Dialogue: 0,0:03:21.40,0:03:23.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,399)}to take a run at him, I will.
# Dialogue: 0,0:03:25.80,0:03:27.00,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}(SIGHS)
# Dialogue: 0,0:03:27.14,0:03:30.04,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}- Really not in the mood, Mom.
# Dialogue: 0,0:03:27.14,0:03:30.04,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,115)}- It could be a lot worse.
# Dialogue: 0,0:03:30.24,0:03:31.40,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,83)}Could be one of the losers
# Dialogue: 0,0:03:30.24,0:03:31.40,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,118)}you dragged home
# Dialogue: 0,0:03:31.61,0:03:32.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(207,400)}when you were a teenager.
# Dialogue: 0,0:03:34.24,0:03:36.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(210,368)}He's old enough to be one
# Dialogue: 0,0:03:34.24,0:03:36.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(192,400)}of the losers I dragged home.
# Dialogue: 0,0:03:38.01,0:03:39.61,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,85)}Look, the more
# Dialogue: 0,0:03:38.01,0:03:39.61,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,118)}a mother fights a daughter
# Dialogue: 0,0:03:39.82,0:03:41.18,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,83)}on who she chooses
# Dialogue: 0,0:03:39.82,0:03:41.18,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}for a boyfriend,
# Dialogue: 0,0:03:41.38,0:03:42.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(209,397)}the more she'll run to him.
# Dialogue: 0,0:03:43.02,0:03:44.04,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(225,400)}How do you know that?
# Dialogue: 0,0:03:44.12,0:03:45.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,400)}I point to your two children.
# Dialogue: 0,0:03:47.69,0:03:50.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,368)}And in the spirit of fairness,
# Dialogue: 0,0:03:47.69,0:03:50.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,400)}I point to you, too.
# Dialogue: 0,0:03:56.60,0:03:58.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,400)}(GROANS) Oh, God.
# Dialogue: 0,0:04:00.70,0:04:04.04,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,83)}Relax.
# Dialogue: 0,0:04:00.70,0:04:04.04,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,118)}I just wanted to apologize.
# Dialogue: 0,0:04:04.24,0:04:06.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(314,368)}- Really?
# Dialogue: 0,0:04:04.24,0:04:06.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(235,399)}- Come here, sit down.
# Dialogue: 0,0:04:07.11,0:04:08.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,368)}Can we just do this
# Dialogue: 0,0:04:07.11,0:04:08.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,400)}in the morning?
# Dialogue: 0,0:04:08.58,0:04:09.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,399)}Damn it, Violet, sit down!
# Dialogue: 0,0:04:12.41,0:04:13.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(317,397)}Please?
# Dialogue: 0,0:04:17.19,0:04:20.78,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,85)}Listen,
# Dialogue: 0,0:04:17.19,0:04:20.78,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(361,118)}it's natural that I worry
# Dialogue: 0,0:04:20.99,0:04:22.98,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}some guy might be taking
# Dialogue: 0,0:04:20.99,0:04:22.98,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}advantage of you.
# Dialogue: 0,0:04:23.83,0:04:25.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(235,400)}Where's the apology?
# Dialogue: 0,0:04:26.33,0:04:27.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(290,368)}- It's coming.
# Dialogue: 0,0:04:26.33,0:04:27.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,397)}- Better come soon.
# Dialogue: 0,0:04:29.80,0:04:30.77,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,83)}One sec.
# Dialogue: 0,0:04:34.07,0:04:35.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,400)}(UTENSILS CRASH)
# Dialogue: 0,0:04:37.24,0:04:38.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(305,400)}Anyway...
# Dialogue: 0,0:04:41.08,0:04:43.60,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,86)}...you and I both know
# Dialogue: 0,0:04:43.81,0:04:45.84,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}that I wasn't always there
# Dialogue: 0,0:04:43.81,0:04:45.84,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}for you,
# Dialogue: 0,0:04:46.05,0:04:48.02,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(360,86)}so you gotta forgive me
# Dialogue: 0,0:04:48.22,0:04:50.81,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}for being
# Dialogue: 0,0:04:48.22,0:04:50.81,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,118)}a little overprotective now.
# Dialogue: 0,0:04:51.02,0:04:52.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(317,368)}- I get it.
# Dialogue: 0,0:04:51.02,0:04:52.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(309,397)}- You do?
# Dialogue: 0,0:04:53.12,0:04:54.59,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}Gregory explained
# Dialogue: 0,0:04:53.12,0:04:54.59,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(358,115)}all this to me.
# Dialogue: 0,0:04:55.19,0:04:56.59,Dialogue2,Unknown,0000,0000,0000,,{\an5\pos(359,86)}He's a psychology professor.
# Dialogue: 0,0:04:56.79,0:04:58.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(277,368)}He actually did
# Dialogue: 0,0:04:56.79,0:04:58.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,397)}his doctoral thesis
# Dialogue: 0,0:04:58.69,0:05:01.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,368)}on the damaging effects
# Dialogue: 0,0:04:58.69,0:05:01.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,399)}of alcoholism on families,
# Dialogue: 0,0:05:01.60,0:05:03.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(220,400)}so he gets that part, too.
# Dialogue: 0,0:05:05.73,0:05:07.36,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(214,400)}Well, isn't that just super.
# Dialogue: 0,0:05:10.04,0:05:11.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(166,368)}(PRETENDING TO YAWN) Oh, hey,
# Dialogue: 0,0:05:10.04,0:05:11.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(192,400)}what are you guys doing up?
# Dialogue: 0,0:05:12.17,0:05:14.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,368)}Oh, give me a break.
# Dialogue: 0,0:05:12.17,0:05:14.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,400)}I heard you breathing up there.
# Dialogue: 0,0:05:15.01,0:05:16.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,400)}Great, then I can jump right in.
# Dialogue: 0,0:05:17.48,0:05:19.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,368)}Why don't we invite Gregory over
# Dialogue: 0,0:05:17.48,0:05:19.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,397)}for dinner?
# Dialogue: 0,0:05:19.71,0:05:21.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,368)}Oh, no. He knows I grew up
# Dialogue: 0,0:05:19.71,0:05:21.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(287,399)}in the circus,
# Dialogue: 0,0:05:21.85,0:05:23.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,365)}he doesn't need
# Dialogue: 0,0:05:21.85,0:05:23.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,397)}to meet the clowns.
# Dialogue: 0,0:05:24.85,0:05:27.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,368)}Honey, I promise, your mom and I
# Dialogue: 0,0:05:24.85,0:05:27.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,397)}will be on our best behavior.
# Dialogue: 0,0:05:27.82,0:05:29.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,365)}We'll make him feel
# Dialogue: 0,0:05:27.82,0:05:29.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(273,400)}really welcome.
# Dialogue: 0,0:05:30.23,0:05:32.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,368)}Well, he did say
# Dialogue: 0,0:05:30.23,0:05:32.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,400)}he'd like to meet you.
# Dialogue: 0,0:05:32.69,0:05:33.99,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,400)}That's a good sign.
# Dialogue: 0,0:05:34.20,0:05:36.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(198,400)}You'll see. He's a terrific guy
# Dialogue: 0,0:05:36.43,0:05:38.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(300,365)}and I think
# Dialogue: 0,0:05:36.43,0:05:38.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,400)}he really cares for me.
# Dialogue: 0,0:05:38.53,0:05:40.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(264,397)}I'm sure he does.
# Dialogue: 0,0:05:41.47,0:05:43.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,400)}Which brings up the question:
# Dialogue: 0,0:05:44.24,0:05:46.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(277,368)}Where are you
# Dialogue: 0,0:05:44.24,0:05:46.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,400)}in the relationship?
# Dialogue: 0,0:05:46.68,0:05:48.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,368)}- What's that supposed to mean?
# Dialogue: 0,0:05:46.68,0:05:48.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,400)}- Are you plankin' him?
# Dialogue: 0,0:05:50.78,0:05:52.04,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,368)}I'm not talking about this
# Dialogue: 0,0:05:50.78,0:05:52.04,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(307,400)}with you.
# Dialogue: 0,0:05:52.25,0:05:53.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,400)}They're plankin'.
# Dialogue: 0,0:05:54.55,0:05:55.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,400)}I'm going to bed now.
# Dialogue: 0,0:05:56.75,0:05:58.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,368)}Okay, but we're gonna do
# Dialogue: 0,0:05:56.75,0:05:58.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(260,400)}the dinner, right?
# Dialogue: 0,0:05:59.02,0:06:00.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(211,400)}Depends. Who's cooking?
# Dialogue: 0,0:06:00.22,0:06:01.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(290,365)}- She'll cook.
# Dialogue: 0,0:06:00.22,0:06:01.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(308,397)}- I'll cook.
# Dialogue: 0,0:06:02.69,0:06:05.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(240,368)}All right, I'll set it up.
# Dialogue: 0,0:06:02.69,0:06:05.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(327,400)}Night.
# Dialogue: 0,0:06:05.59,0:06:06.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(322,368)}- Night.
# Dialogue: 0,0:06:05.59,0:06:06.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(322,400)}- Night.
# Dialogue: 0,0:06:07.10,0:06:08.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(203,400)}I still never got my apology.
# Dialogue: 0,0:06:08.96,0:06:10.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,368)}- Sorry.
# Dialogue: 0,0:06:08.96,0:06:10.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(308,397)}- Too late.
# Dialogue: 0,0:06:13.54,0:06:14.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(305,397)}Shall we?
# Dialogue: 0,0:06:15.54,0:06:17.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(204,368)}(GROANS) I can't go to bed
# Dialogue: 0,0:06:15.54,0:06:17.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(306,397)}after that.
# Dialogue: 0,0:06:17.61,0:06:18.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(199,400)}The second I close my eyes,
# Dialogue: 0,0:06:18.97,0:06:20.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,368)}I'll be picturing
# Dialogue: 0,0:06:18.97,0:06:20.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,400)}Richard Dreyfuss
# Dialogue: 0,0:06:20.54,0:06:21.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,400)}showering with my daughter.
# Dialogue: 0,0:06:24.15,0:06:25.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(315,365)}Thanks.
# Dialogue: 0,0:06:24.15,0:06:25.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,400)}Now I'm not sleeping either.
# Dialogue: 0,0:06:28.28,0:06:30.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(257,400)}(BOTH SHUDDER)
# Dialogue: 0,0:06:31.85,0:06:32.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(328,397)}Wow.
# Dialogue: 0,0:06:33.02,0:06:35.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,365)}- So he's older than me?
# Dialogue: 0,0:06:33.02,0:06:35.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(331,400)}- Yup.
# Dialogue: 0,0:06:35.22,0:06:37.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,367)}Man, I don't know whether to be
# Dialogue: 0,0:06:35.22,0:06:37.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,400)}disgusted or impressed.
# Dialogue: 0,0:06:38.43,0:06:41.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(257,368)}- You're disgusted.
# Dialogue: 0,0:06:38.43,0:06:41.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(278,397)}- I can be both.
# Dialogue: 0,0:06:42.66,0:06:44.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,365)}Do we have
# Dialogue: 0,0:06:42.66,0:06:44.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(193,400)}four matching dinner plates?
# Dialogue: 0,0:06:44.60,0:06:45.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(209,368)}That's what you're worried
# Dialogue: 0,0:06:44.60,0:06:45.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(320,397)}about?
# Dialogue: 0,0:06:45.77,0:06:47.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(306,365)}Your kids
# Dialogue: 0,0:06:45.77,0:06:47.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,400)}don't have matching fathers.
# Dialogue: 0,0:06:51.04,0:06:52.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(240,365)}Mind if I stick around
# Dialogue: 0,0:06:51.04,0:06:52.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(276,397)}and meet him?
# Dialogue: 0,0:06:52.37,0:06:53.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,400)}Yeah, actually, I do.
# Dialogue: 0,0:06:53.64,0:06:55.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,368)}Take the kid that is yours
# Dialogue: 0,0:06:53.64,0:06:55.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(317,400)}and go.
# Dialogue: 0,0:06:55.61,0:06:56.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,400)}(SCOFFS) Whatever.
# Dialogue: 0,0:06:57.31,0:06:58.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,400)}All right, let's hit it.
# Dialogue: 0,0:07:00.02,0:07:01.08,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,400)}(VIOLET LAUGHS)
# Dialogue: 0,0:07:01.08,0:07:02.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(341,397)}Oh.
# Dialogue: 0,0:07:03.12,0:07:04.25,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(338,400)}Hey.
# Dialogue: 0,0:07:06.92,0:07:08.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(295,368)}Hey, Baxter.
# Dialogue: 0,0:07:06.92,0:07:08.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,400)}This is Gregory.
# Dialogue: 0,0:07:09.12,0:07:11.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(273,368)}Gregory, this is
# Dialogue: 0,0:07:09.12,0:07:11.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,400)}my little brother, Roscoe,
# Dialogue: 0,0:07:11.73,0:07:12.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,397)}and Roscoe's dad.
# Dialogue: 0,0:07:13.13,0:07:14.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(341,365)}- Hi.
# Dialogue: 0,0:07:13.13,0:07:14.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,400)}- Hi, nice to meet you.
# Dialogue: 0,0:07:15.10,0:07:16.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,400)}Nice to meet you, too.
# Dialogue: 0,0:07:20.50,0:07:21.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(330,400)}Okay.
# Dialogue: 0,0:07:22.80,0:07:24.10,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,400)}We'll be on our way.
# Dialogue: 0,0:07:25.47,0:07:26.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,400)}Oh, just a heads up.
# Dialogue: 0,0:07:26.98,0:07:29.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,368)}As Violet's former stepfather,
# Dialogue: 0,0:07:26.98,0:07:29.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,400)}I'm keeping my eye on you.
# Dialogue: 0,0:07:30.31,0:07:33.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(208,368)}But as a by standing dude,
# Dialogue: 0,0:07:30.31,0:07:33.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(292,400)}I tip my cap.
# Dialogue: 0,0:07:36.35,0:07:38.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(307,368)}- Let's go.
# Dialogue: 0,0:07:36.35,0:07:38.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(154,400)}- ROSCOE: You're not wearing a cap.
# Dialogue: 0,0:07:40.52,0:07:41.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,400)}BONNIE: Not her usual type.
# Dialogue: 0,0:07:41.96,0:07:44.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(208,368)}Looks like her usual type's
# Dialogue: 0,0:07:41.96,0:07:44.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(283,400)}parole officer.
# Dialogue: 0,0:07:46.49,0:07:48.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(210,397)}It's still not too late to run.
# Dialogue: 0,0:07:48.16,0:07:49.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(287,400)}(CHUCKLES)
# Dialogue: 0,0:07:49.30,0:07:51.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(316,365)}I'm fine.
# Dialogue: 0,0:07:49.30,0:07:51.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,400)}Where can I hang this?
# Dialogue: 0,0:07:51.50,0:07:52.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(229,397)}The closet's back there
# Dialogue: 0,0:07:52.77,0:07:54.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,365)}but that's where
# Dialogue: 0,0:07:52.77,0:07:54.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,400)}my little brother sleeps.
# Dialogue: 0,0:07:54.80,0:07:56.10,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,397)}What?
# Dialogue: 0,0:07:57.97,0:07:59.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(186,367)}- Welcome, welcome, welcome.
# Dialogue: 0,0:07:57.97,0:07:59.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(301,397)}- Welcome.
# Dialogue: 0,0:08:00.14,0:08:01.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(304,397)}Welcome.
# Dialogue: 0,0:08:03.48,0:08:07.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,368)}Yeah, okay.
# Dialogue: 0,0:08:03.48,0:08:07.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(179,400)}Mom, Grandma, this is Gregory.
# Dialogue: 0,0:08:07.88,0:08:10.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(193,368)}- Oh, it is so nice to meet you.
# Dialogue: 0,0:08:07.88,0:08:10.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,400)}- Nice to meet you, too.
# Dialogue: 0,0:08:11.15,0:08:12.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(259,367)}- Please, sit down.
# Dialogue: 0,0:08:11.15,0:08:12.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,397)}- Thanks.
# Dialogue: 0,0:08:13.09,0:08:14.45,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,400)}Would you like a glass of wine?
# Dialogue: 0,0:08:14.66,0:08:16.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(319,368)}Really?
# Dialogue: 0,0:08:14.66,0:08:16.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(195,400)}You keep wine in the house?
# Dialogue: 0,0:08:17.13,0:08:19.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(211,368)}We don't drink but we got
# Dialogue: 0,0:08:17.13,0:08:19.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,400)}a nice Chardonnay for you.
# Dialogue: 0,0:08:19.79,0:08:22.42,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,368)}- Thanks, I'll have a glass.
# Dialogue: 0,0:08:19.79,0:08:22.42,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(310,399)}- Me, too.
# Dialogue: 0,0:08:22.63,0:08:24.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,368)}Oh, honey, you're not old enough
# Dialogue: 0,0:08:22.63,0:08:24.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(312,397)}to drink.
# Dialogue: 0,0:08:24.37,0:08:25.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(186,400)}She's not old enough to drink.
# Dialogue: 0,0:08:28.17,0:08:29.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,400)}Why don't I get the booze?
# Dialogue: 0,0:08:31.27,0:08:34.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(264,365)}So Violet tells us
# Dialogue: 0,0:08:31.27,0:08:34.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,400)}you teach at the junior college.
# Dialogue: 0,0:08:34.48,0:08:36.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(234,400)}Yes, I do. Psychology.
# Dialogue: 0,0:08:36.41,0:08:37.40,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,400)}(GREGORY CHUCKLES)
# Dialogue: 0,0:08:37.48,0:08:38.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,368)}Well, then we have something
# Dialogue: 0,0:08:37.48,0:08:38.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(294,397)}in common.
# Dialogue: 0,0:08:38.81,0:08:40.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,397)}I'm a certified life coach.
# Dialogue: 0,0:08:40.88,0:08:41.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(305,397)}Certified?
# Dialogue: 0,0:08:42.02,0:08:44.28,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(162,368)}(CHUCKLES) Well, that's fabulous,
# Dialogue: 0,0:08:42.02,0:08:44.28,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,400)}because, you know,
# Dialogue: 0,0:08:44.49,0:08:46.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,368)}there are so many fly-by-night
# Dialogue: 0,0:08:44.49,0:08:46.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(290,397)}life coaches.
# Dialogue: 0,0:08:48.22,0:08:49.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(280,400)}Hey, Gregory?
# Dialogue: 0,0:08:49.39,0:08:51.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,368)}You didn't happen to bring
# Dialogue: 0,0:08:49.39,0:08:51.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(186,400)}your own corkscrew, did you?
# Dialogue: 0,0:08:56.20,0:08:58.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,400)}So after my mom had the stroke,
# Dialogue: 0,0:08:59.30,0:09:01.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(186,368)}I took a year off of grad school
# Dialogue: 0,0:08:59.30,0:09:01.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(257,397)}to take care of her
# Dialogue: 0,0:09:01.67,0:09:04.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,368)}which I thought
# Dialogue: 0,0:09:01.67,0:09:04.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,400)}was gonna be hard,
# Dialogue: 0,0:09:04.41,0:09:07.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(291,365)}but it turned
# Dialogue: 0,0:09:04.41,0:09:07.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,400)}into this wonderful experience,
# Dialogue: 0,0:09:07.58,0:09:10.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(272,368)}because we got
# Dialogue: 0,0:09:07.58,0:09:10.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,397)}to know each other as adults.
# Dialogue: 0,0:09:11.51,0:09:14.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,400)}And that was a priceless gift.
# Dialogue: 0,0:09:15.12,0:09:17.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(268,365)}That's beautiful.
# Dialogue: 0,0:09:15.12,0:09:17.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,397)}She would never do that for me.
# Dialogue: 0,0:09:19.32,0:09:20.52,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(295,400)}She's right.
# Dialogue: 0,0:09:21.86,0:09:24.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(254,367)}Well, this was fun.
# Dialogue: 0,0:09:21.86,0:09:24.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(214,400)}I'm gonna grab our coats.
# Dialogue: 0,0:09:25.66,0:09:27.25,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(283,399)}Oh, so soon?
# Dialogue: 0,0:09:27.70,0:09:29.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,367)}You wanted to meet him,
# Dialogue: 0,0:09:27.70,0:09:29.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,400)}you met him, now say good-bye.
# Dialogue: 0,0:09:31.80,0:09:32.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(264,400)}I'll be right there.
# Dialogue: 0,0:09:33.03,0:09:35.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,400)}Listen, I just wanna say...
# Dialogue: 0,0:09:36.34,0:09:38.50,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,368)}...I get that you have
# Dialogue: 0,0:09:36.34,0:09:38.50,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(207,400)}your misgivings about me.
# Dialogue: 0,0:09:38.71,0:09:41.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,368)}If I was in your position,
# Dialogue: 0,0:09:38.71,0:09:41.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,400)}I would feel the exact same way.
# Dialogue: 0,0:09:42.31,0:09:45.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,368)}But you have to know
# Dialogue: 0,0:09:42.31,0:09:45.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,400)}I wasn't looking for this.
# Dialogue: 0,0:09:45.58,0:09:47.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(276,368)}I'm not the guy
# Dialogue: 0,0:09:45.58,0:09:47.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(201,400)}who dates younger women.
# Dialogue: 0,0:09:47.82,0:09:51.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(181,400)}But we just made a connection.
# Dialogue: 0,0:09:52.69,0:09:57.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,368)}And I want to reassure you
# Dialogue: 0,0:09:52.69,0:09:57.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,400)}that I care deeply about Violet.
# Dialogue: 0,0:09:59.86,0:10:01.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(232,368)}- Okay, well, thank you.
# Dialogue: 0,0:09:59.86,0:10:01.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,400)}- Yeah, okay.
# Dialogue: 0,0:10:03.87,0:10:05.36,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,368)}- You ready?
# Dialogue: 0,0:10:03.87,0:10:05.36,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(326,397)}- Yeah.
# Dialogue: 0,0:10:05.83,0:10:11.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,368)}Oh, why don't you take the wine,
# Dialogue: 0,0:10:05.83,0:10:11.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(232,397)}since we can't drink it.
# Dialogue: 0,0:10:11.77,0:10:12.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(300,400)}Or open it.
# Dialogue: 0,0:10:14.84,0:10:16.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(280,368)}Thanks again,
# Dialogue: 0,0:10:14.84,0:10:16.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(242,400)}this was really great.
# Dialogue: 0,0:10:16.44,0:10:17.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(292,400)}Good night.
# Dialogue: 0,0:10:17.51,0:10:18.54,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(278,400)}CHRISTY: Bye.
# Dialogue: 0,0:10:23.79,0:10:25.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(207,365)}I have a terrible confession
# Dialogue: 0,0:10:23.79,0:10:25.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,397)}to make.
# Dialogue: 0,0:10:26.15,0:10:27.21,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,397)}What?
# Dialogue: 0,0:10:27.89,0:10:29.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(189,397)}I like him better than I like her.
# Dialogue: 0,0:10:31.09,0:10:33.25,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,400)}I like him better than I like you.
# Dialogue: 0,0:10:41.24,0:10:43.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(299,368)}Seriously?
# Dialogue: 0,0:10:41.24,0:10:43.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,397)}You left me a to-do list?
# Dialogue: 0,0:10:43.77,0:10:45.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,368)}(SIGHS) I've got an hour
# Dialogue: 0,0:10:43.77,0:10:45.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,400)}to do my homework
# Dialogue: 0,0:10:45.51,0:10:46.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,397)}before I run to the restaurant.
# Dialogue: 0,0:10:47.08,0:10:48.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(201,400)}Who else is gonna vacuum,
# Dialogue: 0,0:10:48.54,0:10:49.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,367)}clean the bathroom,
# Dialogue: 0,0:10:48.54,0:10:49.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(262,400)}sort the laundry?
# Dialogue: 0,0:10:50.15,0:10:52.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,368)}- Hey, I'm not your wife.
# Dialogue: 0,0:10:50.15,0:10:52.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,397)}- You sure about that?
# Dialogue: 0,0:10:53.62,0:10:55.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(285,368)}I go out there
# Dialogue: 0,0:10:53.62,0:10:55.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(262,400)}and earn a living,
# Dialogue: 0,0:10:55.62,0:10:57.45,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,368)}we sleep in the same bed
# Dialogue: 0,0:10:55.62,0:10:57.45,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,397)}and don't have sex.
# Dialogue: 0,0:10:59.05,0:11:00.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,400)}Maybe I am your wife.
# Dialogue: 0,0:11:02.59,0:11:03.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(273,400)}I'm not staying.
# Dialogue: 0,0:11:05.13,0:11:06.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,368)}What do you mean
# Dialogue: 0,0:11:05.13,0:11:06.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,400)}you're not staying?
# Dialogue: 0,0:11:06.59,0:11:07.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(192,400)}I haven't seen you for a week.
# Dialogue: 0,0:11:08.00,0:11:09.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,368)}Yeah, well, after I grab
# Dialogue: 0,0:11:08.00,0:11:09.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,400)}a few of my things,
# Dialogue: 0,0:11:09.76,0:11:11.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(260,368)}you won't see me
# Dialogue: 0,0:11:09.76,0:11:11.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(260,397)}for another week.
# Dialogue: 0,0:11:16.54,0:11:19.67,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,368)}You're just gonna stand there?
# Dialogue: 0,0:11:16.54,0:11:19.67,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,400)}You're not gonna say anything?
# Dialogue: 0,0:11:19.87,0:11:21.50,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,368)}Hey, you're the man
# Dialogue: 0,0:11:19.87,0:11:21.50,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(285,397)}of the house.
# Dialogue: 0,0:11:26.88,0:11:28.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,399)}So, what's the deal?
# Dialogue: 0,0:11:28.52,0:11:30.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(303,368)}You living
# Dialogue: 0,0:11:28.52,0:11:30.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(193,400)}with Professor Higgins now?
# Dialogue: 0,0:11:30.35,0:11:31.55,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(207,397)}His last name is Munchnik.
# Dialogue: 0,0:11:31.75,0:11:33.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(298,368)}By George,
# Dialogue: 0,0:11:31.75,0:11:33.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,400)}she doesn't get the reference.
# Dialogue: 0,0:11:35.82,0:11:37.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,368)}Violet, I just wanna know
# Dialogue: 0,0:11:35.82,0:11:37.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(264,400)}what's going on.
# Dialogue: 0,0:11:38.03,0:11:39.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,368)}You've been spending
# Dialogue: 0,0:11:38.03,0:11:39.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(228,397)}a lot of time over there.
# Dialogue: 0,0:11:39.63,0:11:41.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,368)}Why wouldn't I?
# Dialogue: 0,0:11:39.63,0:11:41.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(258,400)}His condo's great.
# Dialogue: 0,0:11:41.76,0:11:43.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,368)}Plus, he's got a gym
# Dialogue: 0,0:11:41.76,0:11:43.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(278,400)}in the building
# Dialogue: 0,0:11:43.36,0:11:45.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(210,400)}and underground parking.
# Dialogue: 0,0:11:45.50,0:11:47.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,400)}Oh, and he has a housekeeper.
# Dialogue: 0,0:11:47.54,0:11:48.70,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(221,400)}We have a housekeeper.
# Dialogue: 0,0:11:50.91,0:11:53.10,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,368)}Careful or you're sleeping
# Dialogue: 0,0:11:50.91,0:11:53.10,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,400)}on the couch tonight.
# Dialogue: 0,0:11:54.24,0:11:56.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,368)}And you also really like him,
# Dialogue: 0,0:11:54.24,0:11:56.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(327,400)}right?
# Dialogue: 0,0:11:57.65,0:11:58.70,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,399)}Yeah, he's cool.
# Dialogue: 0,0:11:59.75,0:12:02.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,368)}Honey, you don't live with a guy
# Dialogue: 0,0:11:59.75,0:12:02.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,397)}because he's cool.
# Dialogue: 0,0:12:02.22,0:12:04.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(211,365)}You live with him because
# Dialogue: 0,0:12:02.22,0:12:04.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(211,400)}you have feelings for him.
# Dialogue: 0,0:12:04.35,0:12:06.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,368)}Is that what you guys did
# Dialogue: 0,0:12:04.35,0:12:06.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(221,400)}when you were my age?
# Dialogue: 0,0:12:07.06,0:12:09.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,368)}- She always goes to that.
# Dialogue: 0,0:12:07.06,0:12:09.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,400)}- It is the smart play.
# Dialogue: 0,0:12:12.63,0:12:14.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(294,367)}Sweetheart,
# Dialogue: 0,0:12:12.63,0:12:14.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(234,400)}I'm just a little worried
# Dialogue: 0,0:12:14.80,0:12:16.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(295,399)}Mom, relax.
# Dialogue: 0,0:12:16.40,0:12:19.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(238,368)}We're just having fun
# Dialogue: 0,0:12:16.40,0:12:19.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,400)}and Gregory is crazy about me.
# Dialogue: 0,0:12:19.53,0:12:21.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(289,399)}I know he is,
# Dialogue: 0,0:12:21.20,0:12:23.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(241,365)}but I wanna hear that
# Dialogue: 0,0:12:21.20,0:12:23.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,400)}you're crazy about him, too,
# Dialogue: 0,0:12:23.67,0:12:25.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(226,400)}that you're not settling.
# Dialogue: 0,0:12:25.31,0:12:26.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(333,365)}Fine.
# Dialogue: 0,0:12:25.31,0:12:26.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,400)}I'm crazy about him.
# Dialogue: 0,0:12:26.87,0:12:28.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(203,368)}He's the man of my dreams.
# Dialogue: 0,0:12:26.87,0:12:28.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(283,400)}See you later.
# Dialogue: 0,0:12:33.48,0:12:35.18,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(280,400)}(SIGHS) Wow.
# Dialogue: 0,0:12:35.75,0:12:37.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(211,365)}You and I are more in love
# Dialogue: 0,0:12:35.75,0:12:37.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(282,400)}than they are.
# Dialogue: 0,0:12:40.89,0:12:43.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(276,368)}I gotta tell you,
# Dialogue: 0,0:12:40.89,0:12:43.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,400)}I miss Violet being here,
# Dialogue: 0,0:12:44.06,0:12:46.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(203,368)}but I swear I've gotten taller
# Dialogue: 0,0:12:44.06,0:12:46.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(238,397)}since she moved out.
# Dialogue: 0,0:12:47.93,0:12:49.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,365)}That's because
# Dialogue: 0,0:12:47.93,0:12:49.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,400)}you're not hunched over.
# Dialogue: 0,0:12:49.46,0:12:50.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(209,400)}You're not walking scared.
# Dialogue: 0,0:12:51.37,0:12:52.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,397)}You know what I noticed?
# Dialogue: 0,0:12:52.63,0:12:54.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,367)}Ever since she left,
# Dialogue: 0,0:12:52.63,0:12:54.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,400)}my bowels have gone
# Dialogue: 0,0:12:54.44,0:12:55.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(209,400)}from irritable to delightful.
# Dialogue: 0,0:12:57.91,0:12:59.70,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,368)}It's just so nice
# ...
# Dialogue: 0,0:16:06.79,0:16:09.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(183,400)}How unformed her thinking is?
# Dialogue: 0,0:16:10.40,0:16:12.42,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,368)}That's one of the things
# Dialogue: 0,0:16:10.40,0:16:12.42,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,397)}I love about her.
# Dialogue: 0,0:16:13.00,0:16:15.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,368)}She's not jaded, she sees
# Dialogue: 0,0:16:13.00,0:16:15.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,400)}the world with fresh eyes.
# Dialogue: 0,0:16:16.00,0:16:16.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(204,400)}Wait till you see those eyes
# Dialogue: 0,0:16:17.17,0:16:18.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(271,368)}when you drink
# Dialogue: 0,0:16:17.17,0:16:18.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(238,400)}the last Diet Snapple.
# Dialogue: 0,0:16:21.31,0:16:22.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,400)}Don't worry.
# Dialogue: 0,0:16:22.78,0:16:24.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(241,368)}I'll never do anything
# Dialogue: 0,0:16:22.78,0:16:24.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(288,400)}to upset her.
# Dialogue: 0,0:16:24.85,0:16:26.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(189,400)}Oh, if only that were possible.
# Dialogue: 0,0:16:29.18,0:16:32.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,368)}So, do I take that as a "yes,"
# Dialogue: 0,0:16:29.18,0:16:32.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,400)}I have your permission?
# Dialogue: 0,0:16:33.19,0:16:35.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,368)}Gregory, I appreciate you
# Dialogue: 0,0:16:33.19,0:16:35.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(282,400)}coming to us,
# Dialogue: 0,0:16:36.02,0:16:37.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,400)}but it's really not our call.
# Dialogue: 0,0:16:37.59,0:16:39.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,368)}Yeah, Violet might not be
# Dialogue: 0,0:16:37.59,0:16:39.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(313,400)}as ready
# Dialogue: 0,0:16:39.59,0:16:40.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,400)}to settle down as you are.
# Dialogue: 0,0:16:41.03,0:16:42.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(301,400)}I hear you.
# Dialogue: 0,0:16:43.87,0:16:45.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(274,368)}I just can't help
# Dialogue: 0,0:16:43.87,0:16:45.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(281,400)}the way I feel.
# Dialogue: 0,0:16:47.24,0:16:48.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,400)}I'm desperately in love.
# Dialogue: 0,0:16:50.77,0:16:52.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,368)}- Oh, you poor bastard.
# Dialogue: 0,0:16:50.77,0:16:52.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,400)}- Bring it in.
# Dialogue: 0,0:16:56.98,0:16:59.31,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(197,368)}ROSCOE: {\i1}No, I got here first.{\i0}
# Dialogue: 0,0:16:56.98,0:16:59.31,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(288,400)}{\i1}It's my room.{\i0}
# Dialogue: 0,0:16:59.51,0:17:01.71,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(168,400)}CHRISTY: {\i1}Okay, here's a fun idea.{\i0}
# Dialogue: 0,0:17:01.92,0:17:03.89,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(245,368)}{\i1}What if we put a tent{\i0}
# Dialogue: 0,0:17:01.92,0:17:03.89,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(261,400)}{\i1}in the living room{\i0}
# Dialogue: 0,0:17:04.09,0:17:06.38,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(233,368)}{\i1}and you could pretend{\i0}
# Dialogue: 0,0:17:04.09,0:17:06.38,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(199,400)}{\i1}you're camping every night?{\i0}
# Dialogue: 0,0:17:06.92,0:17:08.05,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(197,399)}ROSCOE: {\i1}What am I, seven?{\i0}
# Dialogue: 0,0:17:14.03,0:17:15.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(256,400)}That was pathetic.
# Dialogue: 0,0:17:17.10,0:17:19.36,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(258,368)}What's pathetic is
# Dialogue: 0,0:17:17.10,0:17:19.36,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,397)}I have to return a tent.
# Dialogue: 0,0:17:22.07,0:17:23.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(333,368)}- Hey.
# Dialogue: 0,0:17:22.07,0:17:23.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(333,400)}- Hey.
# Dialogue: 0,0:17:25.17,0:17:28.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,368)}- What brings you by?
# Dialogue: 0,0:17:25.17,0:17:28.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,400)}- I needed to talk to you guys.
# Dialogue: 0,0:17:28.68,0:17:29.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(317,397)}About?
# Dialogue: 0,0:17:31.41,0:17:33.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,368)}Last night at dinner,
# Dialogue: 0,0:17:31.41,0:17:33.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,400)}Gregory proposed to me.
# Dialogue: 0,0:17:35.25,0:17:37.84,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,367)}Yeah, he mentioned
# Dialogue: 0,0:17:35.25,0:17:37.84,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(264,400)}he might do that.
# Dialogue: 0,0:17:38.92,0:17:40.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,368)}- What did you say?
# Dialogue: 0,0:17:38.92,0:17:40.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,400)}- Did you let him down easy?
# Dialogue: 0,0:17:41.09,0:17:43.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,400)}Well, I was going to...
# Dialogue: 0,0:17:44.83,0:17:46.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,365)}...but then he showed me
# Dialogue: 0,0:17:44.83,0:17:46.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(251,400)}this awesome ring,
# Dialogue: 0,0:17:46.23,0:17:47.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(267,400)}and I said "yes!"
# Dialogue: 0,0:17:47.46,0:17:48.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(297,400)}(GIGGLES)
# Dialogue: 0,0:17:51.47,0:17:55.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(283,368)}I am going be
# Dialogue: 0,0:17:51.47,0:17:55.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,400)}Mrs. Gregory Munchnik.
# Dialogue: 0,0:17:59.77,0:18:01.04,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(325,397)}Hello?
# Dialogue: 0,0:18:02.54,0:18:05.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,368)}Your daughter just got engaged.
# Dialogue: 0,0:18:02.54,0:18:05.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,400)}This is good news.
# Dialogue: 0,0:18:05.38,0:18:07.21,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,400)}Yeah, sure, it's good,
# Dialogue: 0,0:18:07.42,0:18:09.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,368)}(CLEARS THROAT)
# Dialogue: 0,0:18:07.42,0:18:09.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(225,400)}if this is what you want.
# Dialogue: 0,0:18:09.58,0:18:10.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,400)}Why wouldn't it be?
# Dialogue: 0,0:18:11.99,0:18:14.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(162,368)}God, my housekeeper was happier
# Dialogue: 0,0:18:11.99,0:18:14.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(220,400)}for me than you two are.
# Dialogue: 0,0:18:15.56,0:18:17.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(221,368)}Honey, this is a big step.
# Dialogue: 0,0:18:15.56,0:18:17.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(241,400)}We just wanna know
# Dialogue: 0,0:18:17.83,0:18:18.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,368)}that you've thought this
# Dialogue: 0,0:18:17.83,0:18:18.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(310,400)}through.
# Dialogue: 0,0:18:19.03,0:18:21.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,368)}Yeah, is this the guy
# Dialogue: 0,0:18:19.03,0:18:21.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,400)}you're gonna be with forever?
# Dialogue: 0,0:18:21.90,0:18:23.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,399)}Well, I doubt it'll be forever,
# Dialogue: 0,0:18:24.13,0:18:26.10,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,368)}but for a first marriage,
# Dialogue: 0,0:18:24.13,0:18:26.10,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(255,400)}he's pretty perfect.
# Dialogue: 0,0:18:29.60,0:18:30.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,397)}Come here.
# Dialogue: 0,0:18:30.74,0:18:31.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,400)}(CLEARS THROAT)
# Dialogue: 0,0:18:32.31,0:18:35.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(273,368)}I'm just worried
# Dialogue: 0,0:18:32.31,0:18:35.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(232,400)}you're marrying a man
# Dialogue: 0,0:18:35.81,0:18:37.21,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,400)}you're not really in love with.
# Dialogue: 0,0:18:37.41,0:18:39.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,368)}Were you in love with Baxter
# Dialogue: 0,0:18:37.41,0:18:39.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,400)}or my dad?
# Dialogue: 0,0:18:39.91,0:18:40.94,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(336,397)}Yes.
# Dialogue: 0,0:18:41.45,0:18:43.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(207,365)}And how did that work out
# Dialogue: 0,0:18:41.45,0:18:43.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,400)}for you?
# Dialogue: 0,0:18:46.29,0:18:48.05,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,400)}Sometimes I just hate this kid.
# Dialogue: 0,0:18:50.66,0:18:52.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(179,400)}Violet, marriage is hard enough
# Dialogue: 0,0:18:53.16,0:18:54.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,368)}when you're desperately in love
# Dialogue: 0,0:18:53.16,0:18:54.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(271,397)}with each other
# Dialogue: 0,0:18:55.13,0:18:57.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(282,368)}and you think
# Dialogue: 0,0:18:55.13,0:18:57.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,400)}it's never gonna end
# Dialogue: 0,0:18:57.47,0:19:00.40,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,368)}But going into it knowing
# Dialogue: 0,0:18:57.47,0:19:00.40,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,400)}it's doomed is just so--
# Dialogue: 0,0:19:00.60,0:19:01.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(305,397)}Realistic?
# Dialogue: 0,0:19:01.84,0:19:03.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,400)}I was gonna say "sad."
# Dialogue: 0,0:19:04.47,0:19:06.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,397)}What is so bad about this?
# Dialogue: 0,0:19:07.24,0:19:10.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(189,365)}I have someone who loves me
# Dialogue: 0,0:19:07.24,0:19:10.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,397)}and wants to take care of me
# Dialogue: 0,0:19:10.68,0:19:12.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,400)}and it's good for you guys,
# Dialogue: 0,0:19:12.38,0:19:14.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(235,368)}because I'm no longer
# Dialogue: 0,0:19:12.38,0:19:14.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,400)}a problem for you anymore.
# Dialogue: 0,0:19:15.28,0:19:17.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,367)}Violet,
# Dialogue: 0,0:19:15.28,0:19:17.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(208,400)}you were never a problem.
# Dialogue: 0,0:19:17.22,0:19:18.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(220,368)}Yeah, we say all the time
# Dialogue: 0,0:19:17.22,0:19:18.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(226,400)}how much we love you.
# Dialogue: 0,0:19:20.09,0:19:21.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(267,365)}There's the face.
# Dialogue: 0,0:19:20.09,0:19:21.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(267,397)}There's the face.
# Dialogue: 0,0:19:24.89,0:19:27.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,400)}Trust me, I know what I'm doing.
# Dialogue: 0,0:19:35.70,0:19:37.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(309,399)}Oh, God.
# Dialogue: 0,0:19:38.01,0:19:39.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,365)}You have to let her
# Dialogue: 0,0:19:38.01,0:19:39.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(295,397)}live her life.
# Dialogue: 0,0:19:39.24,0:19:40.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,400)}She's a grown woman.
# Dialogue: 0,0:19:41.08,0:19:44.10,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(175,365)}VIOLET: {\i1}Mom. Roscoe threw out{\i0}
# Dialogue: 0,0:19:41.08,0:19:44.10,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(253,400)}{\i1}all my teddy bears!{\i0}
# Dialogue: 0,0:19:46.38,0:19:48.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(193,368)}Now we know what to get her
# Dialogue: 0,0:19:46.38,0:19:48.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(259,400)}as a wedding gift.
# Dialogue: 0,0:19:57.56,0:19:58.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(261,400)}What you doing?
# Dialogue: 0,0:19:59.26,0:20:00.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,400)}Working on my dating profile.
# Dialogue: 0,0:20:01.13,0:20:03.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,368)}- EHarmony? Match?
# Dialogue: 0,0:20:01.13,0:20:03.56,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(273,400)}- Senior-Mingle.
# Dialogue: 0,0:20:05.40,0:20:07.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(271,368)}- You're kidding.
# Dialogue: 0,0:20:05.40,0:20:07.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(172,400)}- Maybe Violet's on to something.
# Dialogue: 0,0:20:08.10,0:20:09.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(309,367)}Oh, God,
# Dialogue: 0,0:20:08.10,0:20:09.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(201,400)}you can't be that desperate.
# Dialogue: 0,0:20:10.10,0:20:11.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(303,365)}Check out
# Dialogue: 0,0:20:10.10,0:20:11.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,397)}some of these old dudes.
# Dialogue: 0,0:20:12.27,0:20:13.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(225,400)}This one's 82 years old.
# Dialogue: 0,0:20:13.77,0:20:14.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(228,368)}He's got a beach house
# Dialogue: 0,0:20:13.77,0:20:14.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(306,399)}in Hawaii,
# Dialogue: 0,0:20:14.98,0:20:16.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,397)}a brownstone in San Francisco
# Dialogue: 0,0:20:16.38,0:20:18.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(279,367)}and look here,
# Dialogue: 0,0:20:16.38,0:20:18.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,400)}under special skills:
# Dialogue: 0,0:20:18.71,0:20:20.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,400)}"Can drive at night."
# Dialogue: 0,0:20:21.78,0:20:22.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(300,397)}Slide over.
# Dialogue: 0,0:20:23.48,0:20:24.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(207,400)}I'm gonna give him a poke.
# Dialogue: 0,0:20:24.79,0:20:26.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(180,400)}Careful you don't break his hip.
# Dialogue: 0,0:20:28.56,0:20:30.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,399)}Ooh, take a look at this silver fox.
# Dialogue: 0,0:20:31.33,0:20:33.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(220,368)}22,000 square foot home
# Dialogue: 0,0:20:31.33,0:20:33.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(304,397)}in Carmel.
# Dialogue: 0,0:20:34.33,0:20:36.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,368)}"Enjoys short walks
# Dialogue: 0,0:20:34.33,0:20:36.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(277,397)}on the beach."
# Dialogue: 0,0:20:36.36,0:20:37.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(302,400)}(LAUGHS)
# Dialogue: 0,0:20:38.60,0:20:41.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,368)}Ah, just so we're clear,
# Dialogue: 0,0:20:38.60,0:20:41.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,400)}you're giving up on love?
# Dialogue: 0,0:20:41.80,0:20:43.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(286,365)}I've had love.
# Dialogue: 0,0:20:41.80,0:20:43.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,400)}I want a housekeeper.
# Dialogue: 0,0:20:49.94,0:20:52.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,400)}âª (THEME MUSIC) âª
# Dialogue: 0,0:21:10.03,0:21:12.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,400)}(English US -SDH)

# %% [markdown]
# ## **Step 6 - Applying the above Function on the Entire Data**

# %%
count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    # print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])
    
    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
df['file_content'] = df['content'].apply(decode_method)

df.head()
# Out:
#            num                                               name  \
# 18230  9254799  charmed.s05.e19.nymphs.just.wanna.have.fun.(20...
# 5064   9203148  american.gothic.s01.e05.the.artist.in.his.muse...
# 51601  9397935  call.the.midwife.christmas.special.2022.(2022)...
# 11270  9228156  dynasty.s05.e20.first.kidnapping.and.now.theft...
# 34937  9321247  harry.wild.s01.e04.an.unhappy.happy.is.a.dange...
#
#                                                  content  \
# 18230  b'PK\x03\x04\x14\x00\x00\x00\x08\x004\xab\x99V...
# 5064   b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\x8d\x99V...
# 51601  b'PK\x03\x04\x14\x00\x00\x00\x08\x00%%\x9aVx\x...
# 11270  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xc8\x94\x...
# 34937  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x81\xb2\x...
#
#                                             file_content
# 18230  ï»¿1\r\n00:00:01,835 --> 00:00:04,269\r\n[PANP...
# 5064   ï»¿1\r\n00:00:02,102 --> 00:00:05,095\r\n<i>Pr...
# 51601  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 11270  ï»¿1\r\n00:00:04,968 --> 00:00:06,922\r\nBLAKE...
# 34937  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8250 entries, 18230 to 68553
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           8250 non-null   int64
#  1   name          8250 non-null   object
#  2   content       8250 non-null   object
#  3   file_content  8250 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 322.3+ KB

# %%
df.tail()
# Out:
#            num                                               name  \
# 24646  9279299  in.sickness.and.in.health.s05.e05.episode.5.5....
# 39802  9344377  too.hot.to.handle.s04.e04.flavia.of.the.month....
# 66441  9455317  south.park.s26.e03.japanese.toilets.(2023).eng...
# 74986  9490207  everybody.hates.chris.s04.e08.everybody.hates....
# 68553  9463438  legend.of.the.seeker.s01.e17.deception.(2009)....
#
#                                                  content  \
# 24646  b'PK\x03\x04\x14\x00\x00\x00\x08\x00s\xa1\x99V...
# 39802  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf0\xbc\x...
# 66441  b'PK\x03\x04\x14\x00\x00\x00\x08\x00A_\x9aV\xf...
# 74986  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x11p\x9aV...
# 68553  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xbbd\x9aV...
#
#                                             file_content
# 24646  ï»¿1\r\n00:00:02,800 --> 00:00:05,758\r\n(# CH...
# 39802  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 66441  ï»¿1\r\n00:00:40,123 --> 00:00:41,373\r\nSee, ...
# 74986  1\r\n00:00:03,671 --> 00:00:05,939\r\nGot a li...
# 68553  ï»¿1\r\n00:00:03,004 --> 00:00:04,448\r\nYou b...

# %% [markdown]
# # Data Cleaning

# %%
import re

def clean_text(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    cleaned_text = re.sub(r'[^\x00-\x7F]+', '', cleaned_text)
    cleaned_text = re.sub(r'\d{2}:\d{2}:\d{2}\d{3} --> \d{2}:\d{2}:\d{2},\d{3}', '', cleaned_text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    cleaned_text = cleaned_text.lower().strip()
    
    return cleaned_text

# %%
df['file_content'] = df['file_content'].apply(clean_text)

# %%
df
# Out:
#            num                                               name  \
# 18230  9254799  charmed.s05.e19.nymphs.just.wanna.have.fun.(20...
# 5064   9203148  american.gothic.s01.e05.the.artist.in.his.muse...
# 51601  9397935  call.the.midwife.christmas.special.2022.(2022)...
# 11270  9228156  dynasty.s05.e20.first.kidnapping.and.now.theft...
# 34937  9321247  harry.wild.s01.e04.an.unhappy.happy.is.a.dange...
# ...        ...                                                ...
# 24646  9279299  in.sickness.and.in.health.s05.e05.episode.5.5....
# 39802  9344377  too.hot.to.handle.s04.e04.flavia.of.the.month....
# 66441  9455317  south.park.s26.e03.japanese.toilets.(2023).eng...
# 74986  9490207  everybody.hates.chris.s04.e08.everybody.hates....
# 68553  9463438  legend.of.the.seeker.s01.e17.deception.(2009)....
#
#                                                  content  \
# 18230  b'PK\x03\x04\x14\x00\x00\x00\x08\x004\xab\x99V...
# 5064   b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\x8d\x99V...
# 51601  b'PK\x03\x04\x14\x00\x00\x00\x08\x00%%\x9aVx\x...
# 11270  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xc8\x94\x...
# 34937  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x81\xb2\x...
# ...                                                  ...
# 24646  b'PK\x03\x04\x14\x00\x00\x00\x08\x00s\xa1\x99V...
# 39802  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf0\xbc\x...
# 66441  b'PK\x03\x04\x14\x00\x00\x00\x08\x00A_\x9aV\xf...
# 74986  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x11p\x9aV...
# 68553  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xbbd\x9aV...
#
#                                             file_content
# 18230  panpipe playing xavier i guess my invitation m...
# 5064   ipreviously oni american gothic you left this ...
# 51601  advertise your product or brand here contact w...
# 11270  blake well theres no proof that heart arrhythm...
# 34937  watch any video online with opensubtitles free...
# ...                                                  ...
# 24646  chas and dave in sickness and in health now my...
# 39802  advertise your product or brand here contact w...
# 66441  see stan you gotta choose if you wanna be in g...
# 74986  got a little something for you man she is a fl...
# 68553  you be the hiders ill be the seeker all right ...
#
# [8250 rows x 4 columns]

# %% [markdown]
# ## CHUNKING DOCUMENTS !

# %%
def chunk_text(text, chunk_size=500, overlap=50):
    chunks = []
    words = text.split()
    for start in range(0, len(words), chunk_size - overlap):
        chunks.append(' '.join(words[start:start + chunk_size]))
    return chunks

# %%
df['chunked_text'] = df['file_content'].apply(lambda x: chunk_text(x))

# %%
df
# Out:
#            num                                               name  \
# 18230  9254799  charmed.s05.e19.nymphs.just.wanna.have.fun.(20...
# 5064   9203148  american.gothic.s01.e05.the.artist.in.his.muse...
# 51601  9397935  call.the.midwife.christmas.special.2022.(2022)...
# 11270  9228156  dynasty.s05.e20.first.kidnapping.and.now.theft...
# 34937  9321247  harry.wild.s01.e04.an.unhappy.happy.is.a.dange...
# ...        ...                                                ...
# 24646  9279299  in.sickness.and.in.health.s05.e05.episode.5.5....
# 39802  9344377  too.hot.to.handle.s04.e04.flavia.of.the.month....
# 66441  9455317  south.park.s26.e03.japanese.toilets.(2023).eng...
# 74986  9490207  everybody.hates.chris.s04.e08.everybody.hates....
# 68553  9463438  legend.of.the.seeker.s01.e17.deception.(2009)....
#
#                                                  content  \
# 18230  b'PK\x03\x04\x14\x00\x00\x00\x08\x004\xab\x99V...
# 5064   b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\x8d\x99V...
# 51601  b'PK\x03\x04\x14\x00\x00\x00\x08\x00%%\x9aVx\x...
# 11270  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xc8\x94\x...
# 34937  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x81\xb2\x...
# ...                                                  ...
# 24646  b'PK\x03\x04\x14\x00\x00\x00\x08\x00s\xa1\x99V...
# 39802  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf0\xbc\x...
# 66441  b'PK\x03\x04\x14\x00\x00\x00\x08\x00A_\x9aV\xf...
# 74986  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x11p\x9aV...
# 68553  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xbbd\x9aV...
#
#                                             file_content  \
# 18230  panpipe playing xavier i guess my invitation m...
# 5064   ipreviously oni american gothic you left this ...
# 51601  advertise your product or brand here contact w...
# 11270  blake well theres no proof that heart arrhythm...
# 34937  watch any video online with opensubtitles free...
# ...                                                  ...
# 24646  chas and dave in sickness and in health now my...
# 39802  advertise your product or brand here contact w...
# 66441  see stan you gotta choose if you wanna be in g...
# 74986  got a little something for you man she is a fl...
# 68553  you be the hiders ill be the seeker all right ...
#
#                                             chunked_text
# 18230  [panpipe playing xavier i guess my invitation ...
# 5064   [ipreviously oni american gothic you left this...
# 51601  [advertise your product or brand here contact ...
# 11270  [blake well theres no proof that heart arrhyth...
# 34937  [watch any video online with opensubtitles fre...
# ...                                                  ...
# 24646  [chas and dave in sickness and in health now m...
# 39802  [advertise your product or brand here contact ...
# 66441  [see stan you gotta choose if you wanna be in ...
# 74986  [got a little something for you man she is a f...
# 68553  [you be the hiders ill be the seeker all right...
#
# [8250 rows x 5 columns]

# %%
df['chunked_text']
# Out:
# 18230    [panpipe playing xavier i guess my invitation ...
# 5064     [ipreviously oni american gothic you left this...
# 51601    [advertise your product or brand here contact ...
# 11270    [blake well theres no proof that heart arrhyth...
# 34937    [watch any video online with opensubtitles fre...
#                                ...
# 24646    [chas and dave in sickness and in health now m...
# 39802    [advertise your product or brand here contact ...
# 66441    [see stan you gotta choose if you wanna be in ...
# 74986    [got a little something for you man she is a f...
# 68553    [you be the hiders ill be the seeker all right...
# Name: chunked_text, Length: 8250, dtype: object

# %% [markdown]
# ## BERT EMBEDDINGS for chunked data

# %%
## BERT - “SentenceTransformers” : Generates embeddings which encode semantic information.
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-mpnet-base-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
df["chunk_embeddings"] = df["chunked_text"].apply(lambda x: model.encode(x))

# %%
df['chunk_embeddings']
# Out:
# 18230    [[0.035840474, 0.031651206, -0.0029583517, 0.0...
# 5064     [[0.021123009, 0.07433403, 0.0057303784, 0.003...
# 51601    [[0.05199184, 0.048980944, -0.020183316, 0.051...
# 11270    [[0.023384012, 0.118389376, -0.004994454, -0.0...
# 34937    [[0.016029937, 0.022402475, 0.016657071, 0.011...
#                                ...
# 24646    [[0.023927758, 0.02417276, 0.0030255115, -0.04...
# 39802    [[0.08386179, 0.044809118, -0.005196778, -0.00...
# 66441    [[0.0523822, 0.080413654, 0.0035326094, 0.0235...
# 74986    [[0.040766783, 0.07189492, -0.013499531, 0.003...
# 68553    [[0.01893767, 0.07143243, 0.012997342, 0.04420...
# Name: chunk_embeddings, Length: 8250, dtype: object

# %%
df.to_csv('embedded_df_10_percent.csv', index=False)
# Download link
from IPython.display import FileLink
FileLink('embedded_df_10_percent.csv')
# Out:
# /Users/eleshalapravalika/Downloads/SEARCH ENGINE PROJECT/embedded_df_10_percent.csv

# %%
df_embed = pd.read_csv('embedded_df_10_percent.csv')

# %%
df_embed
# Out:
#           num                                               name  \
# 0     9254799  charmed.s05.e19.nymphs.just.wanna.have.fun.(20...
# 1     9203148  american.gothic.s01.e05.the.artist.in.his.muse...
# 2     9397935  call.the.midwife.christmas.special.2022.(2022)...
# 3     9228156  dynasty.s05.e20.first.kidnapping.and.now.theft...
# 4     9321247  harry.wild.s01.e04.an.unhappy.happy.is.a.dange...
# ...       ...                                                ...
# 8245  9279299  in.sickness.and.in.health.s05.e05.episode.5.5....
# 8246  9344377  too.hot.to.handle.s04.e04.flavia.of.the.month....
# 8247  9455317  south.park.s26.e03.japanese.toilets.(2023).eng...
# 8248  9490207  everybody.hates.chris.s04.e08.everybody.hates....
# 8249  9463438  legend.of.the.seeker.s01.e17.deception.(2009)....
#
#                                                 content  \
# 0     b'PK\x03\x04\x14\x00\x00\x00\x08\x004\xab\x99V...
# 1     b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\x8d\x99V...
# 2     b'PK\x03\x04\x14\x00\x00\x00\x08\x00%%\x9aVx\x...
# 3     b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xc8\x94\x...
# 4     b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x81\xb2\x...
# ...                                                 ...
# 8245  b'PK\x03\x04\x14\x00\x00\x00\x08\x00s\xa1\x99V...
# 8246  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf0\xbc\x...
# 8247  b'PK\x03\x04\x14\x00\x00\x00\x08\x00A_\x9aV\xf...
# 8248  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x11p\x9aV...
# 8249  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xbbd\x9aV...
#
#                                            file_content  \
# 0     panpipe playing xavier i guess my invitation m...
# 1     ipreviously oni american gothic you left this ...
# 2     advertise your product or brand here contact w...
# 3     blake well theres no proof that heart arrhythm...
# 4     watch any video online with opensubtitles free...
# ...                                                 ...
# 8245  chas and dave in sickness and in health now my...
# 8246  advertise your product or brand here contact w...
# 8247  see stan you gotta choose if you wanna be in g...
# 8248  got a little something for you man she is a fl...
# 8249  you be the hiders ill be the seeker all right ...
#
#                                            chunked_text  \
# 0     ['panpipe playing xavier i guess my invitation...
# 1     ['ipreviously oni american gothic you left thi...
# 2     ['advertise your product or brand here contact...
# 3     ['blake well theres no proof that heart arrhyt...
# 4     ['watch any video online with opensubtitles fr...
# ...                                                 ...
# 8245  ['chas and dave in sickness and in health now ...
# 8246  ['advertise your product or brand here contact...
# 8247  ['see stan you gotta choose if you wanna be in...
# 8248  ['got a little something for you man she is a ...
# 8249  ['you be the hiders ill be the seeker all righ...
#
#                                        chunk_embeddings
# 0     [[ 0.03584047  0.03165121 -0.00295835 ...  0.0...
# 1     [[ 0.02112301  0.07433403  0.00573038 ...  0.0...
# 2     [[ 0.05199184  0.04898094 -0.02018332 ...  0.0...
# 3     [[ 0.02338401  0.11838938 -0.00499445 ...  0.0...
# 4     [[ 0.01602994  0.02240247  0.01665707 ...  0.0...
# ...                                                 ...
# 8245  [[ 2.3927758e-02  2.4172761e-02  3.0255115e-03...
# 8246  [[ 0.08386179  0.04480912 -0.00519678 ...  0.0...
# 8247  [[ 0.0523822   0.08041365  0.00353261 ...  0.0...
# 8248  [[ 0.04076678  0.07189492 -0.01349953 ...  0.0...
# 8249  [[ 1.89376697e-02  7.14324266e-02  1.29973423e...
#
# [8250 rows x 6 columns]
